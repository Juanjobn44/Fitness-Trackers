# %%
import numpy as np
import pandas as pd
from statistics import mean

# %% [markdown]
# 1.- Uno de los primeros pasos para realizar un buen análisis de datos es familiarizarnos
# con los datos que contiene el fichero a analizar. Para ello, calcularemos los estadísticos
# descriptivos elementales de las variables del fichero. Una vez cargados los datos en
# nuestro programa Python (utilizando la librería Pandas), calcula los siguientes valores
# para cada una de las variables:
# • Número de muestras (valores distintos de missing)
# • Media y desviación estándar de aquellas variables en las que tenga sentido
# (numéricas)
# • Valor mínimo y valor máximo de aquellas variables en las que tenga sentido
# (numéricas)

# %%
data = pd.read_csv("C:/Users/Juanjo/Escritorio/MasterDataScience/ProgramacionOrientada/PracticaPy/Fitness_trackers.csv")
df = pd.DataFrame(data)

#Corrección comas
df.loc[:,'Selling Price'] = df.loc[:,'Selling Price'].str.replace(',','')
df.loc[:,'Original Price'] = df.loc[:,'Original Price'].str.replace(',','')
#Visualización del dataframe
df.dtypes
# Out:
# Brand Name                         object
# Device Type                        object
# Model Name                         object
# Color                              object
# Selling Price                      object
# Original Price                     object
# Display                            object
# Rating (Out of 5)                 float64
# Strap Material                     object
# Average Battery Life (in days)      int64
# Reviews                            object
# dtype: object

# %%
#Corregimos tipos de variables.
df['Selling Price'] = df['Selling Price'].astype('float64')
df['Original Price'] = df['Original Price'].astype('float64')
df.dtypes
# Out:
# Brand Name                         object
# Device Type                        object
# Model Name                         object
# Color                              object
# Selling Price                     float64
# Original Price                    float64
# Display                            object
# Rating (Out of 5)                 float64
# Strap Material                     object
# Average Battery Life (in days)      int64
# Reviews                            object
# dtype: object

# %%
#Numero de muestras
df.count()
# Out:
# Brand Name                        565
# Device Type                       565
# Model Name                        565
# Color                             565
# Selling Price                     565
# Original Price                    565
# Display                           565
# Rating (Out of 5)                 514
# Strap Material                    565
# Average Battery Life (in days)    565
# Reviews                            78
# dtype: int64

# %%
#Visualizamos los NAs.
df.isna().sum()
# Out:
# Brand Name                          0
# Device Type                         0
# Model Name                          0
# Color                               0
# Selling Price                       0
# Original Price                      0
# Display                             0
# Rating (Out of 5)                  51
# Strap Material                      0
# Average Battery Life (in days)      0
# Reviews                           487
# dtype: int64

# %%
num = pd.DataFrame(df, columns=['Selling Price','Original Price','Rating (Out of 5)','Average Battery Life (in days)'])
num.head()
# Out:
#    Selling Price  Original Price  Rating (Out of 5)  \
# 0         2499.0          2999.0                4.1
# 1         2099.0          2499.0                4.2
# 2         1722.0          2099.0                3.5
# 3         2469.0          2999.0                4.1
# 4         1799.0          2199.0                4.3
#
#    Average Battery Life (in days)
# 0                              14
# 1                              14
# 2                              14
# 3                              14
# 4                               7

# %%
#Media de variables numéricas
num.mean()
# Out:
# Selling Price                     22110.373451
# Original Price                    25365.361062
# Rating (Out of 5)                     4.229961
# Average Battery Life (in days)        9.026549
# dtype: float64

# %%
#STD variables numéricas
num.std()
# Out:
# Selling Price                     19914.926066
# Original Price                    20384.028759
# Rating (Out of 5)                     0.390827
# Average Battery Life (in days)        7.868670
# dtype: float64

# %% [markdown]
# 2.- Hay datos que nos interesa analizar basándonos en agrupaciones, para darle un
# sentido a nuestro análisis en base a esa agrupación. Basándonos en las siguientes
# agrupaciones:
# • Por tipo de dispositivo
# • Por precio de venta. Estableceremos cuatro grupos en base a la media del precio
# de venta de cada tipo de dispositivo:
# o Smartwatches con un precio inferior o igual a la media de precios de
# venta de estos dispositivos
# o Smartwatches con un precio superior a la media de precios de venta de
# estos dispositivos
# o Fitnessbands con un precio inferior o igual a la media de precios de venta
# de estos dispositivos
# o Fitnessbands con un precio superior a la media de precios de venta de
# estos dispositivos
# • Por marca

# %%
#Agrupación por Device Type
df_ordenado = df.sort_values('Device Type')
df_tipo = df_ordenado.set_index(['Device Type', 'Brand Name'])
df_tipo
# Out:
#                                  Model Name                      Color  \
# Device Type Brand Name
# FitnessBand Xiaomi             Smart Band 5                      Black
#             Huawei      Band 2 Pro Activity                Pink, Black
#             Huawei                   Band 6  Pink, Black, Teal, Orange
#             Huawei                   Band 2                      Black
#             Huawei                   Band 2                       Blue
# ...                                     ...                        ...
# Smartwatch  FOSSIL          FB-01 Hybrid HR                      Black
#             FOSSIL         Gen 5 Garrett HR                      Black
#             FOSSIL       Latitude Hybrid HR                      Black
#             FOSSIL        Gen 5 Julianna HR                       Gold
#             FOSSIL                   Gen 5E           Grey, Multicolor
#
#                         Selling Price  Original Price         Display  \
# Device Type Brand Name
# FitnessBand Xiaomi             2499.0          2999.0  AMOLED Display
#             Huawei             2199.0          5999.0  PMOLED Display
#             Huawei             4490.0          9990.0  PMOLED Display
#             Huawei             4599.0          4599.0  PMOLED Display
#             Huawei             6999.0          6999.0  PMOLED Display
# ...                               ...             ...             ...
# Smartwatch  FOSSIL            12396.0         14995.0  AMOLED Display
#             FOSSIL            14995.0         22995.0  AMOLED Display
#             FOSSIL            12396.0         14995.0  AMOLED Display
#             FOSSIL            18495.0         18495.0  AMOLED Display
#             FOSSIL            18495.0         18495.0  AMOLED Display
#
#                         Rating (Out of 5)              Strap Material  \
# Device Type Brand Name
# FitnessBand Xiaomi                    4.1  Thermoplastic polyurethane
#             Huawei                    4.1                    Silicone
#             Huawei                    4.4                    Silicone
#             Huawei                    4.1                    Silicone
#             Huawei                    4.2                    Silicone
# ...                                   ...                         ...
# Smartwatch  FOSSIL                    4.0                    Silicone
#             FOSSIL                    4.1             Stainless Steel
#             FOSSIL                    4.3             Stainless Steel
#             FOSSIL                    3.8             Stainless Steel
#             FOSSIL                    4.2             Stainless Steel
#
#                         Average Battery Life (in days) Reviews
# Device Type Brand Name
# FitnessBand Xiaomi                                  14     NaN
#             Huawei                                   7     NaN
#             Huawei                                   7     NaN
#             Huawei                                   7     NaN
#             Huawei                                   7     NaN
# ...                                                ...     ...
# Smartwatch  FOSSIL                                  14     NaN
#             FOSSIL                                   2     NaN
#             FOSSIL                                  14     NaN
#             FOSSIL                                   2     NaN
#             FOSSIL                                   1     NaN
#
# [565 rows x 9 columns]

# %%
#Media Fitnessband
df_fb = df_tipo.loc['FitnessBand']
media_fb = df_fb['Selling Price'].mean()
media_fb
# Out:
# 5479.213333333333

# %%
#Agrego nueva columna 'Comparativa'
#df_fb.loc['Comparativa'] = df_fb.loc['Selling Price'] 
df_tipo['Comparativa'] = np.nan

# %%
#Media Smartwatch
df_sw = df_tipo.loc['Smartwatch']
media_sw = df_sw['Selling Price'].mean()
media_sw
sw_altos = df_sw.loc[df_sw['Selling Price'] >= media_sw]

# %%
#Agrupación por marca
df_ordenado = df.sort_values('Brand Name')
df_marca = df.set_index(['Brand Name', 'Device Type'])
df_marca
# Out:
#                                    Model Name             Color  \
# Brand Name Device Type
# Xiaomi     FitnessBand           Smart Band 5             Black
#            FitnessBand           Smart Band 4             Black
#            FitnessBand               HMSH01GE             Black
#            FitnessBand           Smart Band 5             Black
#            FitnessBand                 Band 3             Black
# ...                                       ...               ...
# Huawei     Smartwatch             Watch 36456             Black
#            Smartwatch   GT Fortuna-B19S Sport             Black
# GOQii      FitnessBand                     HR             Black
#            FitnessBand                  Vital             Black
# FOSSIL     Smartwatch                  Gen 5E  Grey, Multicolor
#
#                         Selling Price  Original Price         Display  \
# Brand Name Device Type
# Xiaomi     FitnessBand         2499.0          2999.0  AMOLED Display
#            FitnessBand         2099.0          2499.0  AMOLED Display
#            FitnessBand         1722.0          2099.0     LCD Display
#            FitnessBand         2469.0          2999.0  AMOLED Display
#            FitnessBand         1799.0          2199.0    OLED Display
# ...                               ...             ...             ...
# Huawei     Smartwatch         55000.0         55000.0  AMOLED Display
#            Smartwatch         13990.0         20990.0  AMOLED Display
# GOQii      FitnessBand         1999.0          1999.0    OLED Display
#            FitnessBand         3499.0          3499.0    OLED Display
# FOSSIL     Smartwatch         18495.0         18495.0  AMOLED Display
#
#                         Rating (Out of 5)              Strap Material  \
# Brand Name Device Type
# Xiaomi     FitnessBand                4.1  Thermoplastic polyurethane
#            FitnessBand                4.2  Thermoplastic polyurethane
#            FitnessBand                3.5                     Leather
#            FitnessBand                4.1  Thermoplastic polyurethane
#            FitnessBand                4.3                     Plastic
# ...                                   ...                         ...
# Huawei     Smartwatch                 4.1                    Silicone
#            Smartwatch                 4.1                   Elastomer
# GOQii      FitnessBand                3.8                    Silicone
#            FitnessBand                3.7  Thermoplastic polyurethane
# FOSSIL     Smartwatch                 4.2             Stainless Steel
#
#                         Average Battery Life (in days) Reviews
# Brand Name Device Type
# Xiaomi     FitnessBand                              14     NaN
#            FitnessBand                              14     NaN
#            FitnessBand                              14     NaN
#            FitnessBand                              14     NaN
#            FitnessBand                               7     NaN
# ...                                                ...     ...
# Huawei     Smartwatch                               14     NaN
#            Smartwatch                               14     NaN
# GOQii      FitnessBand                               7     NaN
#            FitnessBand                               7     NaN
# FOSSIL     Smartwatch                                1     NaN
#
# [565 rows x 9 columns]
